# %% [markdown]
# # _The Sparks Foundation_

# %% [markdown]
# ### Name:- Niraj Namdeo Palve

# %% [markdown]
# #### ***Task3:- Exploratory Data Analysis- Retail***

# %% [markdown]
# ### Problem Statement: Perform 'Exploratory Data Analysis' on 'Sample Superstore' Dataset

# %%
import pandas as pd         # Importing necessary libraries
import numpy as np  
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.offline as plot_off 
import plotly.graph_objects as plot_graph

# %%
sample_sup = pd.read_csv("SampleSuperstore.csv")   # Loading Dataset

# %%
sample_sup.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
# Checking row & column of dataset
sample_sup.shape
# Out:
# (9994, 13)

# %%
sample_sup.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Checking whether null values are present or not
sample_sup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### Null values are not present in dataset

# %%
# Print the summary of dataset(mean, median, mode, min, max)
sample_sup.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# #### Postal Code does not carry any information, so that we will drop "Postal Code" from the dataset and as dataset is of United States only, so we can also drop "Country" from our dataset.

# %%
sample_sup1 = sample_sup.drop("Postal Code", axis=1)
sample_sup1 = sample_sup.drop("Country", axis=1)

# %%
sample_sup1.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Let's visualize the relation between 'Sales' and 'Profit'

# %%
plt.scatter(x=sample_sup1.Sales,y=sample_sup1.Profit,)
plt.xlabel('Sales', fontsize = 20)
plt.ylabel('Profit', fontsize = 20)
plt.show()

# %% [markdown]
# ### From scatter plot, we can say that maximum sales is in between 0 - 6000 and also sometimes when sales increasing, profit is also increased.

# %% [markdown]
# ### Let's visualize the relation between 'Discount' and 'Profit'

# %%
plt.scatter(x=sample_sup1.Discount,y=sample_sup1.Profit,)
plt.xlabel('Discount', fontsize = 20)
plt.ylabel('Profit', fontsize = 20)
plt.show()

# %% [markdown]
# #### From above scatter plot, we can say that giving more discount leads to decreasing profit. Hence, discount should not be more than 20%.

# %% [markdown]
# ### Let's check trend of Sales for "Segment"

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Segment', data = sample_sup1)
plt.show()

# %%
sample_sup1['Segment'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("Segment-wise sales pie chart");

# %% [markdown]
# #### Sales for Consumer segment is more as compared to other two segments.Hence, business should focused more on supplying good service and quality when sale is in consumer segment inorder to increase more sales.

# %% [markdown]
# ### Let's check Region wise trend of Sales

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = "Region", data = sample_sup1)
plt.show()

# %%
sample_sup1['Region'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("Region-wise sales pie chart");

# %% [markdown]
# #### "West" and "East" regions buying more products than "South" and "Central".Hence, business should focused on giving good quality products in "west" and "East" region and also business should focused on generating insights behind less sales in "South" and "Central" region.

# %% [markdown]
# ### Let's check Category wise trend of Sales

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = "Category", data = sample_sup1)
plt.show()

# %%
sample_sup1['Category'].value_counts().plot.pie(figsize =(6, 6), autopct ='%.2f')
plt.title("Region-wise sales pie chart");

# %% [markdown]
# #### "Office Supplies" category has more profit compared to other categories. Business should be focused on increasing profit in "Furniture" and "Technology".

# %%
plt.figure(figsize = (12,6))
sns.countplot(x ='Sub-Category', data = sample_sup1)
plt.xticks(rotation = (90))
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = "State", data = sample_sup1)
plt.xticks(rotation = (90))
plt.show()

# %% [markdown]
# ## Sales is more in states like California, Washington, Texas, Pennsylvania, lllinois, New York and Ohio. Hence, Company can expand their business in these states to increase profit.
